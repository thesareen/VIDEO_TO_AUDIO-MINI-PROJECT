# %% [markdown]
# <a href="https://colab.research.google.com/github/thesareen/VIDEO_TO_AUDIO-MINI-PROJECT/blob/main/VIDEO_TO_AUDIO_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install moviepy #video to audio converter
import moviepy.editor as mp
my_clip = mp.VideoFileClip(r"/content/WhatsApp Video 2023-06-06 at 23.08.49.mp4")
my_clip.audio.write_audiofile(r"my_result.mp3")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# MoviePy - Writing audio in my_result.mp3
# MoviePy - Done.
